# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
area=[2600,3000,3200,3600,4000]
price=[550000,565000,610000,680000,725000]

# %%
plt.xlabel('area')
plt.ylabel('Price')
plt.title("home price prediction")
plt.plot(area,price,marker='*', color='r')
